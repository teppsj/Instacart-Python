# %% [markdown]
# # 01. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing Dataframe

# %%
# Create a string path

path = r'C:\Users\rasmu\Documents\CareerFoundry\A4 Instacart Basket Analysis\02 Data'

# %%
# Importing Dataframe

ords_prods_merge = pd.read_pickle(os.path.join(path, 'Prepd Data', 'orders_products_merged.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True       196.0                1.0
# 1                     NaN         True     14084.0                2.0
# 2                     NaN         True     12427.0                3.0
# 3                     NaN         True     26088.0                4.0
# 4                     NaN         True     26405.0                5.0
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
ords_prods_merge.shape
# Out:
# (32641268, 18)

# %%
# Creating a subset of the dataframe

df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
# 5   2398795        1             2                   3                  7
# 6   2398795        1             2                   3                  7
# 7   2398795        1             2                   3                  7
# 8   2398795        1             2                   3                  7
# 9   2398795        1             2                   3                  7
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True       196.0                1.0
# ...

# %%
# Testing the groupby() function

df.groupby('product_name')

# %%
# Aggregating data w/ agg()

df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              14.794925
# 2.0              17.085793
# 3.0              17.892742
# 4.0              17.880137
# 5.0              15.108513
# 6.0              15.352869
# 7.0              17.682741
# 8.0              16.496386
# 9.0              15.944846
# 10.0             20.104831
# 11.0             16.483104
# 12.0             15.614125
# 13.0             16.458631
# 14.0             17.523399
# 15.0             15.673392
# 16.0             18.012021
# 17.0             15.842139
# 18.0             19.349156
# 19.0             17.625805
# 20.0             17.113240
# 21.0             22.009038

# %%
# using mean() instead of agg()

df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1.0     14.794925
# 2.0     17.085793
# 3.0     17.892742
# 4.0     17.880137
# 5.0     15.108513
# 6.0     15.352869
# 7.0     17.682741
# 8.0     16.496386
# 9.0     15.944846
# 10.0    20.104831
# 11.0    16.483104
# 12.0    15.614125
# 13.0    16.458631
# 14.0    17.523399
# 15.0    15.673392
# 16.0    18.012021
# 17.0    15.842139
# 18.0    19.349156
# 19.0    17.625805
# 20.0    17.113240
# 21.0    22.009038
# Name: order_number, dtype: float64

# %%
# performing multi aggregates - mean, min, max

df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1.0              14.794925   1  99
# 2.0              17.085793   1  98
# 3.0              17.892742   1  99
# 4.0              17.880137   1  99
# 5.0              15.108513   1  99
# 6.0              15.352869   1  99
# 7.0              17.682741   1  99
# 8.0              16.496386   1  91
# 9.0              15.944846   1  99
# 10.0             20.104831   1  99
# 11.0             16.483104   1  99
# 12.0             15.614125   1  99
# 13.0             16.458631   1  99
# 14.0             17.523399   1  99
# 15.0             15.673392   1  99
# 16.0             18.012021   1  99
# 17.0             15.842139   1  99
# 18.0             19.349156   1  99
# 19.0             17.625805   1  99
# 20.0             17.113240   1  99
# 21.0             22.009038   1  97

# %%
# performing transform() function

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# 5    2398795        1             2                   3                  7
# 6    2398795        1             2                   3                  7
# 7    2398795        1             2                   3                  7
# 8    2398795        1             2                   3                  7
# 9    2398795        1             2                   3                  7
# 10   2398795        1             2                   3                  7
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# ..       ...      ...           ...                 ...                ...
# 95    738281        2             4                   2                 10
# 96    738281        2             4                   2                 10
# 97   1673511        2             5                   3                 11
# 98   1673511        2             5                   3                 11
# 99   1673511        2             5                   3                 11
#
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# 5    2398795        1             2                   3                  7
# 6    2398795        1             2                   3                  7
# 7    2398795        1             2                   3                  7
# 8    2398795        1             2                   3                  7
# 9    2398795        1             2                   3                  7
# 10   2398795        1             2                   3                  7
# ...

# %% [markdown]
# # 05. Deriving Columns w/ loc()

# %%
# Creating loyalty flags

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    16381472
# Loyal customer      10679578
# New customer         5580218
# Name: loyalty_flag, dtype: int64

# %%
# Checking the interpretations & flags assigned correctly

ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1  Regular customer             1
# 1         1  Regular customer             1
# 2         1  Regular customer             1
# 3         1  Regular customer             1
# 4         1  Regular customer             1
# 5         1  Regular customer             2
# 6         1  Regular customer             2
# 7         1  Regular customer             2
# 8         1  Regular customer             2
# 9         1  Regular customer             2
# 10        1  Regular customer             2
# 11        1  Regular customer             3
# 12        1  Regular customer             3
# 13        1  Regular customer             3
# 14        1  Regular customer             3
# 15        1  Regular customer             3
# 16        1  Regular customer             4
# 17        1  Regular customer             4
# 18        1  Regular customer             4
# 19        1  Regular customer             4
# ...
